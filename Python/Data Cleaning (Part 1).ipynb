# %% [markdown]
# # Lending Club Data Cleaning Code

# %% [markdown]
# Part 1 of 3:
# This code should take Lending Club data and clean it for the purpose of modeling, this includes caping and flooring, imputing, and eliminating irrelevant columns. At the end of the code there are reviews of the final output to make sure we have everything we need for future scoring (Part 3) and that the build data seems to make sense. Notebook developed by Tim Horan.

# %% [markdown]
# ### Import necessary Python Packages

# %%
import pandas as pd
import time
import datetime
import numpy as np 
import json

from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook

# %% [markdown]
# ### Create DF from downloaded CSVs

# %%
# Combine Historic Datasets from Lending Club (download from https://www.lendingclub.com/info/download-data.action)

dataSetA = 'LoanStats3a_securev1.csv' #2007-2011
dataSetB = 'LoanStats3b_securev1.csv' #2012-2013
dataSetC = 'LoanStats3c_securev1.csv' #2014
dataSetD = 'LoanStats3d_securev1.csv' #2015

#Define function and create dataframe from Lending Club raw CSVs
def importCSVLendingClub(dataset, headerRows, footerRows, index):
    """
    Input: Raw CSV of Lending Club historic performance
    Output: Data frames with specified index and appropriate headers and footers dropped
    """
    return pd.io.parsers.read_csv(dataset,sep = ',', index_col = index, skiprows = headerRows, skipfooter = footerRows,  engine='python')

#Execute above functions with index 'id'
df_a = importCSVLendingClub(dataSetA, 1, 2, 'id')
df_b = importCSVLendingClub(dataSetB, 1, 2, 'id')
df_c = importCSVLendingClub(dataSetC, 1, 2, 'id')
df_d = importCSVLendingClub(dataSetD, 1, 2, 'id')

#Combine 3 dataframes and drop duplicates and make sure there are no nulls of 'member_id' variable
df = pd.concat([df_a, df_b, df_c, df_d]).drop_duplicates()
df = df[df.index.notnull()]

# %% [markdown]
# ### Add date data format and make all dates relative to appropriate date (mostly relative to issue date)

# %%
# Define function to trasform and compare two dates and output the number of months between time
def timeBetweenDatesM(timeZero, timeCompare):
    """
    Input: Two date fields (make sure field can be converted to a date using the "to_datetime" funciton before using)
    Output: A single numeric output that specifies the number of months between the two dates
    """
    timeZeroF = pd.to_datetime(timeZero,format="%b-%Y")
    timeCompareF = pd.to_datetime(timeCompare,format="%b-%Y")
    return (timeCompareF - timeZeroF).astype('timedelta64[M]')

# Add a 'today' column to leverage for relative timing (could also hardcode a date if desired)
# df['today'] = datetime.date.today().strftime("%b-%Y")
#buildMonth = datetime.date.today().strftime("%b-%Y")
#Hardcoded version of 'today'
df['today'] = 'Feb-2016'

# Apply definition to create realtive variables
df['last_pymnt_d_R'] = timeBetweenDatesM(df['issue_d'], df['last_pymnt_d'])
df['earliest_cr_line_R'] = timeBetweenDatesM(df['issue_d'], df['earliest_cr_line'])
df['last_pymnt_d_R'] = timeBetweenDatesM(df['issue_d'], df['last_pymnt_d'])
df['next_pymnt_d_R'] = timeBetweenDatesM(df['issue_d'], df['next_pymnt_d'])
df['last_credit_pull_d_R'] = timeBetweenDatesM(df['issue_d'], df['last_credit_pull_d'])
df['loan_age'] = timeBetweenDatesM(df['issue_d'], df['today'])

#Keep loans older than 18 months
df = df[df['loan_age'] >= 18]

# %% [markdown]
# ### Review CO/Default Data and eliminate out of policy loans

# %%
# Create an inPolicy flag to track accounts in Policy
df['inPolicy'] = df['loan_status'].map(lambda i: 1 if i in [
'Current',
'Fully Paid',
'Charged Off',
'Late (31-120 days)',
'In Grace Period',
'Late (16-30 days)',
'Default'
] else 0)

#Drop out of policy loans
df = df[df.inPolicy == 1]

# %% [markdown]
# ### Create and Add CO Flag and DQ/CO Flag

# %%
# Define charge off function 
def chargeOffFlag(loan_status, last_pymnt_d_R, n):
    """
    Input: Loan status whether they charged off or not; the time of last payment to enable the creation of a time based
    CO flag (e.g. helps determine if someone charges off after 18M or after); The charge off period you aim to make a 
    CO flag for
    Output: A 1/0 flag at the account level
    """
    if (loan_status == 'Charged Off' or loan_status == 'Default') and last_pymnt_d_R <= (n-6):
        return 1
    else:
        return 0

#Apply the charge off function to dataframe
df['CO18M'] = df.apply(lambda row: chargeOffFlag(row['loan_status'], row['last_pymnt_d_R'], 18), axis=1)

# %% [markdown]
# ### Fix data type for revol_util and int_rate (object to float)

# %%
#Both fields were objects so needed to shift them to numbers and divide the answers by 100
df['int_rate'] = df.int_rate.replace('%','',regex=True).astype('float')/100
df['revol_util'] = df.revol_util.replace('%','',regex=True).astype('float')/100

# %% [markdown]
# ### Drop Columns that we won't have at time of decisioning or judgementally want to exclude

# %%
#Dataset included post booking variables and variables that judgementally were excluded
irrelevantVariable = [
'funded_amnt',
'funded_amnt_inv',
'initial_list_status',
'pymnt_plan',
'out_prncp',
'out_prncp_inv',
'total_pymnt',
'total_pymnt_inv',
'total_rec_prncp',
'total_rec_int',
'total_rec_late_fee', 
'recoveries',
'collection_recovery_fee',
'last_pymnt_d',
'last_pymnt_amnt',
'next_pymnt_d', 
'last_credit_pull_d', 
'last_fico_range_high', 
'last_fico_range_low', 
'next_pymnt_d_R', 
'last_pymnt_d_R', 
'last_credit_pull_d_R',
'pymnt_plan',
'loan_status', #Function of target variable
'today', #Not relevant
'policy_code', #Has only a single case
'inPolicy', #Has only a single case
'earliest_cr_line', #Has a lot of different date values so dropping for now
#Following metrics could be helpful in the future with text analytics
'url',
'desc',
'title',
'emp_title',
'issue_d',
#Following metrics are all nulls as of January 2016
'annual_inc_joint',
'annual_inc_joint',
'dti_joint',
'verification_status_joint',
'open_acc_6m',
'open_il_6m',
'open_il_12m',
'open_il_24m',
'mths_since_rcnt_il',
'total_bal_il',
'il_util',
'open_rv_12m',
'open_rv_24m',
'max_bal_bc',
'all_util',
'inq_fi',
'total_fi_tl',
'inq_last_12m',
'total_cu_tl',
'open_act_il',
'revol_bal_joint',
'sec_app_fico_range_low',   
'sec_app_fico_range_high',   
'sec_app_earliest_cr_line',
'sec_app_inq_last_6mths',
'sec_app_mort_acc',
'sec_app_open_acc',
'sec_app_revol_util',
'sec_app_open_act_il',
'sec_app_num_rev_accts',    
'sec_app_chargeoff_within_12_mths',    
'sec_app_collections_12_mths_ex_med',
'sec_app_mths_since_last_major_derog',    
'deferral_term',    
'hardship_amount',    
'hardship_length',    
'hardship_dpd',    
'orig_projected_additional_accrued_interest',    
'hardship_payoff_balance_amount',   
'hardship_last_payment_amount',
'settlement_amount',    
'settlement_percentage',    
'settlement_term',    
'hardship_type',
'hardship_reason',
'hardship_status',
'hardship_start_date',
'hardship_end_date',
'payment_plan_start_date',   
'hardship_loan_status',
'debt_settlement_flag_date',    
'settlement_status',
'settlement_date',
'hardship_flag',
'debt_settlement_flag']

#Update dataframe with only the relevant variables
relevantVariable = []
for i in df.columns:
    if i not in irrelevantVariable:
        relevantVariable.append(i)
df = df[relevantVariable]

# %% [markdown]
# ### Clean remaining variables

# %%
#Leveraged initial cap/floor/impute numeric variable code written by Randy C. from Capital One labs as a starting point
#for overall variable cleaning code

def createOneMinusList(df, listStart):
    """
    Input: Dataframe and a list that we will bump against the df to find the one minus of the df columns
    Output: List of variables that is the one minus of the initial list
    """
    oneMinusList = []
    for col in df.columns:
        if col not in listStart:
            oneMinusList.append(col)
    return oneMinusList

def cap_and_floor(series, floor=0.01, cap=0.99):
    """
    Takes in a numberic series (typically column from dataframe) and returns 4 series:
    1) The final capped, floored, and imputed initial series - 'series'
    2) A 1/0 flag for when an instance was floored - 'floored'
    3) A 1/0 flag for when an instance was capped - 'capped'
    4) A 1/0 flag for when an instance was imputed - 'imputed'
    
    Options:
    - "floor" percentile at which to floor instances
    - "cap" percentile at which to cap instances
    """
    impute = (pd.isnull(series)).apply(int)
    meanVal = series.mean()
    series = series.fillna(meanVal)
    
    floorVal = series.quantile(floor)
    floored = (series < floorVal).apply(int)
    series = series.apply(lambda x: x if x > floorVal else floorVal)
    
    capVal = series.quantile(cap)
    capped = (series > capVal).apply(int)
    series = series.apply(lambda x: x if x < capVal else capVal)
    
    return series, floored, capped, impute, meanVal, floorVal, capVal

def char_null_imput(series):
    """
    Takes in a an object series (typically column from dataframe) and returns 2 series:
    1) The final imputed initial series - 'series'
    2) A 1/0 flag for when an instance was imputed - 'imputed'
    """
    imputeVal = 'Null'
    impute = (pd.isnull(series)).apply(int)
    series = series.fillna(imputeVal)
    
    return series, impute, imputeVal 

def cleanDF(df, donotAlterList = []):
    """
    Takes in a dataframe and a list of fields not to alter (this would likely include your target variable 
    and variables you wouldn't want to cap/floor/impute)
    
    Outputs 
    1) A final cleaned dataframe all nulls should be imputed unless null fields come from list of fields not to 
    alter
    2) A dictionary that contains the variables treatments (cap/floor/impute values) by column
    """
    dfFinal = df[[]]
    d_treatment = {}
    dfDoNotAlter = df.loc[:,donotAlterList]
    alterList = createOneMinusList(df, donotAlterList)
    
    dfNumeric = df.loc[:,alterList].select_dtypes(include=['number'])
    for col in dfNumeric.columns:
        series, floor, capped, impute, meanVal, floorVal, capVal = cap_and_floor(dfNumeric[col])
        dfNumeric[col] = series
        dfNumeric[col+"_cap"] = capped
        dfNumeric[col+"_floor"] = floor
        dfNumeric[col+"_imputed"] = impute
        d_treatment[col] = {col+"_cap":capVal,col+"_floor":floorVal,col+"_imputed":meanVal}
    
    dfObject = df.loc[:,alterList].select_dtypes(include=['object'])
    for col in dfObject.columns:
        series, impute, imputeVal  = char_null_imput(dfObject[col])
        dfObject[col] = series
        dfObject[col+"_imputed"] = impute
        d_treatment[col] = {col+"_imputed":imputeVal}
        
    dfFinal = pd.concat([dfFinal, dfDoNotAlter, dfNumeric, dfObject], axis=1, join_axes=[dfFinal.index])
    return dfFinal, d_treatment

#Create a list of variables not to alter in any way
donotAlterList = ['member_id', 'loan_amnt', 'int_rate', 'installment', 'CO18M', 'loan_age']

#Apply above functions and return updated dataframe and treatment dictionary
dfFinal, d_treatment = cleanDF(df, donotAlterList)

# %% [markdown]
# ### Transform all object variables to mean of target variable

# %%
def charCleanUp(seriesName, seriesTarget, dfContainer, d_treatment_charVars):
    """
    Input: A non-numberic series from a df, a target variable from a df, the df it came from, and a dictionary
    to use to capture variable treatment and applies changes to the df and dictionary (no return)
    Output: None
    """
    #Capture list of all unique variables in the series
    uniqueValue = np.unique(dfContainer[seriesName].values)
    meanDict = {}
    #Create dataframe with only the seriesName and seriesTarget
    dfSubset0 = dfContainer.loc[:,[seriesName, seriesTarget]]
    for i in uniqueValue:
        #Create a subset dictionary with only one unique field from list
        dfSubset = dfSubset0[dfSubset0[seriesName] == i]
        #Assign the mean seriesTarget to the dictionary
        meanDict[i] = round(dfSubset[seriesTarget].mean(),4)
    #Create a 'Missing' entry into the dictionary in case during scoring a ne field appears
    meanDict['Missing'] = round(dfSubset0[seriesTarget].mean(),4)
    #Apply dictionary on series
    dfContainer[seriesName] = dfContainer.apply(lambda row: meanDict[row[seriesName]], axis=1)
    #Add variable specific dictionary to broader treatment dictionary
    d_treatment_charVars[seriesName] = meanDict

def dfCharCleanUp(df, d_treatment_charVars, seriesTarget, donotAlterList = []):
    """
    Input: Dataframe, dictionary to capture variables treatments, the series target, and a list of columns not to
    include
    Output: None
    """
    alterList = createOneMinusList(df, donotAlterList)     
    dfObject = df.loc[:,alterList].select_dtypes(include=['object'])
    for col in dfObject.columns:
        charCleanUp(col, seriesTarget, df, d_treatment_charVars)

d_treatment_charVars = {}
dfCharCleanUp(dfFinal, d_treatment_charVars, 'CO18M', donotAlterList)

# %% [markdown]
# ### Capture key variable means by Lending Club Grades to help track significant changes in data or catch errors during the scoring portion of this code

# %%
#Temporarily add back orginal grade to collect mean data at the Lending Club Grade group
dfFinal['grade_group'] = df['grade']

# %%
def captureVaribleMetrics(df, dictionary, variable, groupByVariable):
    """
    Input: Dataframe, dictionary to capture outputs, target column name, and group by column name
    Output: None
    """
    #Create a dataframe that captures mean levels by the groupByVariable
    dfTemp = df.groupby(groupByVariable)[variable].mean()
    dictMeans = {}
    for i in range (0,len(dfTemp)):
        #Capture means by groupByVariable in dictionary
        dictMeans[dfTemp.index[i]] = dfTemp[i]
    #Add dictionary to broader treatment dictionary
    dictionary[variable] = dictMeans

excludeColumns = [
    'member_id',
    'loan_age',
    'grade_group'
]

d_means_by_LC_grades = {}

# Apply defintiion on select columns
for i in dfFinal:
    if i not in excludeColumns and '_cap' not in i and '_floor' not in i and 'impute' not in i:
        captureVaribleMetrics(dfFinal,d_means_by_LC_grades,i,'grade_group')

# %%
#Remove 'grade_Group' from final df
dfFinal = dfFinal.drop('grade_group', 1)

# %% [markdown]
# ### Capture all columns in final dataset and datatype (exclude target variable) - will be leveraged as part of scoring section to make sure all needed variables are captured

# %%
dTypeDict = {}

for i in dfFinal:
    if i not in ['CO18M']:
        dTypeDict[i] = str(dfFinal[i].dtype)

# %% [markdown]
# ### Seperate data into build and validation samples

# %%
def createBuildAndValidationSamples(dfFinal, ageCutOff):
    """
    Generate Build and Validation datasets based on an age cutoff and using 3 months of bookings for the validaiton
    sample
    Input: The cleaned dataframe and the age cutoff
    """
    dfFinalBuild = dfFinal[(dfFinal.loan_age >= (ageCutOff+3))]
    dfFinalValidation = dfFinal[(dfFinal.loan_age >= ageCutOff) & (dfFinal.loan_age < (ageCutOff+3))]
    return dfFinalBuild, dfFinalValidation

# %%
#Generate build and validation samples based on target variables
dfFinalBuild, dfFinalValidation = createBuildAndValidationSamples(dfFinal, 18)

# %% [markdown]
# ### Save cleaned build and validation datasets and data treatment

# %%
writeLocation = ''

dfFinalBuild.to_csv(writeLocation+"build_step1.csv",',')
dfFinalValidation.to_csv(writeLocation+"validation_step1.csv",',')

with open(writeLocation+'d_treatment_charVars.json', 'w') as fp:
    json.dump(d_treatment_charVars, fp)
    
with open(writeLocation+'d_treatment.json', 'w') as fp:
    json.dump(d_treatment, fp)
    
with open(writeLocation+'d_means_by_LC_grades.json', 'w') as fp:
    json.dump(d_means_by_LC_grades, fp)

with open(writeLocation+'dTypeDict.json', 'w') as fp:
    json.dump(dTypeDict, fp)

# %% [markdown]
# ### Data cleaning code should pass the below reviews

# %% [markdown]
# #### Final Dataset has all numeric columns in preperation for Gradient Boosting

# %%
for i in dfFinal:
    if dfFinal[i].dtype not in ['float', 'int']:
        print(i + ' - ' + dfFinal[i].dtype)
else:
    print('Pass: All fields float or int dtype!')
# Out:
# Pass: All fields float or int dtype!

# %% [markdown]
# #### Review all variables that were imputed more than 5% of the time to get comfortable

# %%
for i in dfFinal:
    mean = dfFinal[i].mean()
    if '_imputed' in i and mean > 0.05:
        print('Imputations: ' + i + ' - ' +  str(mean))
# Out:
# Imputations: mths_since_last_delinq_imputed - 0.5496270252292488
# Imputations: mths_since_last_record_imputed - 0.8746192384240562
# Imputations: mths_since_last_major_derog_imputed - 0.8020066201042112
# Imputations: tot_coll_amt_imputed - 0.17824393025134225
# Imputations: tot_cur_bal_imputed - 0.17824393025134225
# Imputations: total_rev_hi_lim_imputed - 0.17824393025134225
# Imputations: acc_open_past_24mths_imputed - 0.12480269027520417
# Imputations: avg_cur_bal_imputed - 0.1782756053911088
# Imputations: bc_open_to_buy_imputed - 0.13261589141762087
# Imputations: bc_util_imputed - 0.13314645000871067
# Imputations: mo_sin_old_il_acct_imputed - 0.20635297719917856
# Imputations: mo_sin_old_rev_tl_op_imputed - 0.17824656984632278
# Imputations: mo_sin_rcnt_rev_tl_op_imputed - 0.17824656984632278
# Imputations: mo_sin_rcnt_tl_imputed - 0.17824393025134225
# Imputations: mort_acc_imputed - 0.12480269027520417
# Imputations: mths_since_recent_bc_imputed - 0.13177913980878775
# Imputations: mths_since_recent_bc_dlq_imputed - 0.7982267200920691
# Imputations: mths_since_recent_inq_imputed - 0.21376759949953278
# Imputations: mths_since_recent_revol_delinq_imputed - 0.7141107468470038
# Imputations: num_accts_ever_120_pd_imputed - 0.17824393025134225
# Imputations: num_actv_bc_tl_imputed - 0.17824393025134225
# Imputations: num_actv_rev_tl_imputed - 0.17824393025134225
# Imputations: num_bc_sats_imputed - 0.1473976233086795
# Imputations: num_bc_tl_imputed - 0.17824393025134225
# Imputations: num_il_tl_imputed - 0.17824393025134225
# Imputations: num_op_rev_tl_imputed - 0.17824393025134225
# Imputations: num_rev_accts_imputed - 0.17824393025134225
# Imputations: num_rev_tl_bal_gt_0_imputed - 0.17824393025134225
# Imputations: num_sats_imputed - 0.1473976233086795
# Imputations: num_tl_120dpd_2m_imputed - 0.19518221124150711
# Imputations: num_tl_30dpd_imputed - 0.17824393025134225
# Imputations: num_tl_90g_dpd_24m_imputed - 0.17824393025134225
# Imputations: num_tl_op_past_12m_imputed - 0.17824393025134225
# Imputations: pct_tl_nvr_dlq_imputed - 0.1786477882833658
# Imputations: percent_bc_gt_75_imputed - 0.13285345496587003
# Imputations: tot_hi_cred_lim_imputed - 0.17824393025134225
# Imputations: total_bal_ex_mort_imputed - 0.12480269027520417
# Imputations: total_bc_limit_imputed - 0.12480269027520417
# Imputations: total_il_high_credit_limit_imputed - 0.17824393025134225

# %% [markdown]
# #### Have necessary dicitonary to capture build capping, flooring, and imputations to review and save for the scoring portion of the code (Part 3)

# %%
for i in d_treatment:
    print(i)
    print(d_treatment[i])
    print()
# Out:
# total_rev_hi_lim
# {'total_rev_hi_lim_cap': 123000.0, 'total_rev_hi_lim_imputed': 29782.106916057164, 'total_rev_hi_lim_floor': 3400.0}
#
# verification_status
# {'verification_status_imputed': 'Null'}
#
# mort_acc
# {'mort_acc_floor': 0.0, 'mort_acc_imputed': 1.846621326135147, 'mort_acc_cap': 8.0}
#
# total_il_high_credit_limit
# {'total_il_high_credit_limit_imputed': 36811.90940161057, 'total_il_high_credit_limit_cap': 174095.55, 'total_il_high_credit_limit_floor': 0.0}
#
# num_bc_sats
# {'num_bc_sats_imputed': 4.652095168805436, 'num_bc_sats_cap': 12.0, 'num_bc_sats_floor': 1.0}
#
# fico_range_high
# {'fico_range_high_cap': 799.0, 'fico_range_high_imputed': 701.1033295851084, 'fico_range_high_floor': 664.0}
#
# dti
# {'dti_cap': 33.77, 'dti_imputed': 16.890464146381376, 'dti_floor': 1.61}
#
# mo_sin_rcnt_tl
# {'mo_sin_rcnt_tl_imputed': 8.505989033756371, 'mo_sin_rcnt_tl_floor': 0.0, 'mo_sin_rcnt_tl_cap': 45.0}
#
# purpose
# {'purpose_imputed': 'Null'}
#
# mo_sin_rcnt_rev_tl_op
# {'mo_sin_rcnt_rev_tl_op_floor': 0.0, 'mo_sin_rcnt_rev_tl_op_cap': 75.0, 'mo_sin_rcnt_rev_tl_op_imputed': 13.596868796536018}
#
# num_accts_ever_120_pd
# {'num_accts_ever_120_pd_imputed': 0.4069234450836602, 'num_accts_ever_120_pd_cap': 5.0, 'num_accts_ever_120_pd_floor': 0.0}
#
# chargeoff_within_12_mths
# {'chargeoff_within_12_mths_imputed': 0.007009160748699807, 'chargeoff_within_12_mths_floor': 0.0, 'chargeoff_within_12_mths_cap': 0.0}
#
# revol_bal
# {'revol_bal_cap': 76786.0499999994, 'revol_bal_floor': 212.45000000000027, 'revol_bal_imputed': 15834.091905418032}
#
# pct_tl_nvr_dlq
# {'pct_tl_nvr_dlq_cap': 100.0, 'pct_tl_nvr_dlq_floor': 66.7, 'pct_tl_nvr_dlq_imputed': 94.8404311525038}
#
# num_il_tl
# {'num_il_tl_imputed': 8.132857294286568, 'num_il_tl_cap': 31.0, 'num_il_tl_floor': 0.0}
#
# mths_since_last_record
# {'mths_since_last_record_floor': 31.0, 'mths_since_last_record_cap': 113.0, 'mths_since_last_record_imputed': 76.78658947368422}
#
# revol_util
# {'revol_util_floor': 0.016, 'revol_util_cap': 0.976, 'revol_util_imputed': 0.563486532909664}
#
# collections_12_mths_ex_med
# {'collections_12_mths_ex_med_floor': 0.0, 'collections_12_mths_ex_med_cap': 0.0, 'collections_12_mths_ex_med_imputed': 0.007209799625122099}
#
# delinq_2yrs
# {'delinq_2yrs_cap': 3.0, 'delinq_2yrs_floor': 0.0, 'delinq_2yrs_imputed': 0.2712685365557509}
#
# tot_coll_amt
# {'tot_coll_amt_cap': 2344.5499999999884, 'tot_coll_amt_floor': 0.0, 'tot_coll_amt_imputed': 178.11351379132014}
#
# num_op_rev_tl
# {'num_op_rev_tl_floor': 2.0, 'num_op_rev_tl_imputed': 8.153874321837087, 'num_op_rev_tl_cap': 20.0}
#
# inq_last_6mths
# {'inq_last_6mths_floor': 0.0, 'inq_last_6mths_imputed': 0.8294372911420471, 'inq_last_6mths_cap': 4.0}
#
# sub_grade
# {'sub_grade_imputed': 'Null'}
#
# mo_sin_old_il_acct
# {'mo_sin_old_il_acct_floor': 13.0, 'mo_sin_old_il_acct_cap': 263.0, 'mo_sin_old_il_acct_imputed': 127.03380450327602}
#
# total_bal_ex_mort
# {'total_bal_ex_mort_imputed': 44910.5674664093, 'total_bal_ex_mort_cap': 199814.09999999998, 'total_bal_ex_mort_floor': 3017.0}
#
# mths_since_last_major_derog
# {'mths_since_last_major_derog_cap': 76.0, 'mths_since_last_major_derog_imputed': 41.97770934154568, 'mths_since_last_major_derog_floor': 9.0}
#
# home_ownership
# {'home_ownership_imputed': 'Null'}
#
# pub_rec
# {'pub_rec_floor': 0.0, 'pub_rec_imputed': 0.14834259831171506, 'pub_rec_cap': 2.0}
#
# tot_hi_cred_lim
# {'tot_hi_cred_lim_floor': 8800.0, 'tot_hi_cred_lim_cap': 684814.399999998, 'tot_hi_cred_lim_imputed': 167493.34026512998}
#
# mo_sin_old_rev_tl_op
# {'mo_sin_old_rev_tl_op_floor': 41.0, 'mo_sin_old_rev_tl_op_cap': 451.0, 'mo_sin_old_rev_tl_op_imputed': 181.94297149538414}
#
# num_tl_30dpd
# {'num_tl_30dpd_floor': 0.0, 'num_tl_30dpd_cap': 0.0026050449860111334, 'num_tl_30dpd_imputed': 0.0026050449860111334}
#
# open_acc
# {'open_acc_cap': 26.0, 'open_acc_floor': 3.0, 'open_acc_imputed': 11.0601220548719}
#
# total_acc
# {'total_acc_floor': 6.0, 'total_acc_imputed': 24.88936929517535, 'total_acc_cap': 59.0}
#
# pub_rec_bankruptcies
# {'pub_rec_bankruptcies_cap': 1.0, 'pub_rec_bankruptcies_imputed': 0.1022348333593372, 'pub_rec_bankruptcies_floor': 0.0}
#
# avg_cur_bal
# {'avg_cur_bal_cap': 68042.04999999987, 'avg_cur_bal_floor': 572.0, 'avg_cur_bal_imputed': 13651.211684928383}
#
# disbursement_method
# {'disbursement_method_imputed': 'Null'}
#
# zip_code
# {'zip_code_imputed': 'Null'}
#
# mths_since_last_delinq
# {'mths_since_last_delinq_floor': 3.0, 'mths_since_last_delinq_imputed': 34.337096036853396, 'mths_since_last_delinq_cap': 79.0}
#
# fico_range_low
# {'fico_range_low_imputed': 697.103255676449, 'fico_range_low_floor': 660.0, 'fico_range_low_cap': 795.0}
#
# num_rev_accts
# {'num_rev_accts_floor': 4.0, 'num_rev_accts_imputed': 15.129481335864499, 'num_rev_accts_cap': 38.0}
#
# mths_since_recent_bc_dlq
# {'mths_since_recent_bc_dlq_imputed': 40.227639617482765, 'mths_since_recent_bc_dlq_floor': 7.0, 'mths_since_recent_bc_dlq_cap': 77.0}
#
# delinq_amnt
# {'delinq_amnt_floor': 0.0, 'delinq_amnt_cap': 0.0, 'delinq_amnt_imputed': 8.328207239881113}
#
# grade
# {'grade_imputed': 'Null'}
#
# tax_liens
# {'tax_liens_cap': 1.0, 'tax_liens_floor': 0.0, 'tax_liens_imputed': 0.028750788660188435}
#
# bc_util
# {'bc_util_imputed': 65.84251531650042, 'bc_util_cap': 100.8, 'bc_util_floor': 0.9}
#
# num_bc_tl
# {'num_bc_tl_floor': 2.0, 'num_bc_tl_imputed': 8.823952280458307, 'num_bc_tl_cap': 23.0}
#
# term
# {'term_imputed': 'Null'}
#
# annual_inc
# {'annual_inc_imputed': 73038.20898032446, 'annual_inc_floor': 18980.0, 'annual_inc_cap': 240000.0}
#
# num_actv_bc_tl
# {'num_actv_bc_tl_cap': 10.0, 'num_actv_bc_tl_floor': 0.0, 'num_actv_bc_tl_imputed': 3.7111066141160673}
#
# bc_open_to_buy
# {'bc_open_to_buy_cap': 60285.649999999965, 'bc_open_to_buy_floor': 0.0, 'bc_open_to_buy_imputed': 8229.570125226335}
#
# acc_open_past_24mths
# {'acc_open_past_24mths_floor': 0.0, 'acc_open_past_24mths_cap': 12.0, 'acc_open_past_24mths_imputed': 4.114945787402169}
#
# num_tl_90g_dpd_24m
# {'num_tl_90g_dpd_24m_floor': 0.0, 'num_tl_90g_dpd_24m_cap': 2.0, 'num_tl_90g_dpd_24m_imputed': 0.0793494775455401}
#
# acc_now_delinq
# {'acc_now_delinq_imputed': 0.00345259023455441, 'acc_now_delinq_cap': 0.0, 'acc_now_delinq_floor': 0.0}
#
# mths_since_recent_inq
# {'mths_since_recent_inq_floor': 0.0, 'mths_since_recent_inq_imputed': 7.012878490302524, 'mths_since_recent_inq_cap': 23.0}
#
# mths_since_recent_revol_delinq
# {'mths_since_recent_revol_delinq_imputed': 36.02075562285334, 'mths_since_recent_revol_delinq_cap': 77.0, 'mths_since_recent_revol_delinq_floor': 5.0}
#
# total_bc_limit
# {'total_bc_limit_floor': 500.0, 'total_bc_limit_cap': 88900.0, 'total_bc_limit_imputed': 19878.87048090118}
#
# emp_length
# {'emp_length_imputed': 'Null'}
#
# addr_state
# {'addr_state_imputed': 'Null'}
#
# percent_bc_gt_75
# {'percent_bc_gt_75_cap': 100.0, 'percent_bc_gt_75_imputed': 52.26262344185198, 'percent_bc_gt_75_floor': 0.0}
#
# num_sats
# {'num_sats_cap': 26.0, 'num_sats_imputed': 11.300911750592096, 'num_sats_floor': 4.0}
#
# application_type
# {'application_type_imputed': 'Null'}
#
# tot_cur_bal
# {'tot_cur_bal_floor': 3906.4500000000003, 'tot_cur_bal_cap': 609357.849999998, 'tot_cur_bal_imputed': 138462.01129709397}
#
# num_tl_op_past_12m
# {'num_tl_op_past_12m_imputed': 1.8674703439237568, 'num_tl_op_past_12m_floor': 0.0, 'num_tl_op_past_12m_cap': 6.0}
#
# num_tl_120dpd_2m
# {'num_tl_120dpd_2m_imputed': 0.0007510609966481034, 'num_tl_120dpd_2m_floor': 0.0, 'num_tl_120dpd_2m_cap': 0.0007510609966481034}
#
# num_actv_rev_tl
# {'num_actv_rev_tl_floor': 1.0, 'num_actv_rev_tl_imputed': 5.732033701765713, 'num_actv_rev_tl_cap': 15.0}
#
# earliest_cr_line_R
# {'earliest_cr_line_R_cap': -50.0, 'earliest_cr_line_R_imputed': -190.09020023967523, 'earliest_cr_line_R_floor': -463.0}
#
# num_rev_tl_bal_gt_0
# {'num_rev_tl_bal_gt_0_cap': 15.0, 'num_rev_tl_bal_gt_0_floor': 1.0, 'num_rev_tl_bal_gt_0_imputed': 5.719108053154481}
#
# mths_since_recent_bc
# {'mths_since_recent_bc_imputed': 25.113197049756476, 'mths_since_recent_bc_floor': 1.0, 'mths_since_recent_bc_cap': 128.0}

# %% [markdown]
# #### Have necessary dicitonary to capture Char treatment to also leverage in Part 3

# %%
for i in d_treatment_charVars:
    if len(d_treatment_charVars[i]) < 20:
        print(i + ' - ' + str(len(d_treatment_charVars[i])))
        print(d_treatment_charVars[i])
        print()

for i in d_treatment_charVars:
    if len(d_treatment_charVars[i]) >= 20:
        print(i + ' - ' + str(len(d_treatment_charVars[i])))
        print()
# Out:
# purpose - 15
# {'vacation': 0.0631, 'wedding': 0.0508, 'home_improvement': 0.0457, 'house': 0.0592, 'debt_consolidation': 0.0535, 'moving': 0.0862, 'major_purchase': 0.0453, 'renewable_energy': 0.0816, 'educational': 0.0585, 'car': 0.0399, 'credit_card': 0.0392, 'small_business': 0.1062, 'Missing': 0.0517, 'other': 0.0711, 'medical': 0.0711}
#
# grade - 8
# {'D': 0.0764, 'G': 0.1469, 'F': 0.1253, 'Missing': 0.0517, 'E': 0.0971, 'C': 0.054, 'B': 0.0341, 'A': 0.017}
#
# home_ownership - 6
# {'NONE': 0.0444, 'RENT': 0.0608, 'OTHER': 0.0625, 'Missing': 0.0517, 'MORTGAGE': 0.0441, 'OWN': 0.0539}
#
# verification_status - 4
# {'Not Verified': 0.0429, 'Missing': 0.0517, 'Verified': 0.0563, 'Source Verified': 0.0551}
#
# term - 3
# {' 60 months': 0.0682, 'Missing': 0.0517, ' 36 months': 0.0457}
#
# emp_length - 13
# {'Missing': 0.0517, 'Null': 0.0676, '8 years': 0.0513, '1 year': 0.0543, '2 years': 0.0541, '3 years': 0.0516, '6 years': 0.0549, '4 years': 0.0529, '7 years': 0.052, '10+ years': 0.0452, '5 years': 0.0515, '< 1 year': 0.0602, '9 years': 0.0555}
#
# disbursement_method - 2
# {'Missing': 0.0517, 'Cash': 0.0517}
#
# application_type - 2
# {'Individual': 0.0517, 'Missing': 0.0517}
#
# zip_code - 878
#
# addr_state - 51
#
# sub_grade - 36

# %% [markdown]
# #### Review mean dictionary also to gut check new scoring datasets (to be incorporated into Part 3)

# %%
for i in d_means_by_LC_grades:
    print(i)
    print(d_means_by_LC_grades[i])
    print()
# Out:
# total_rev_hi_lim
# {'D': 25554.95755221656, 'G': 27375.80085925098, 'F': 24965.863588767614, 'E': 25895.504961976796, 'C': 26871.231908690173, 'B': 29233.974430077134, 'A': 38964.59595787266}
#
# verification_status
# {'D': 0.05259049672887542, 'G': 0.055361925009661556, 'F': 0.05470652393641574, 'E': 0.05401691959389805, 'C': 0.05214694996029431, 'B': 0.050693643091334804, 'A': 0.0500547311267541}
#
# loan_amnt
# {'D': 15024.651885954285, 'G': 21292.413993042133, 'F': 18539.881007075255, 'E': 17725.704835685734, 'C': 14228.875595710882, 'B': 12899.66171853939, 'A': 13183.257829178503}
#
# mort_acc
# {'D': 1.673289273791782, 'G': 1.841581044728715, 'F': 1.6518593012250773, 'E': 1.7383026426699408, 'C': 1.7919836156046804, 'B': 1.808675232381551, 'A': 2.1237055140010135}
#
# total_il_high_credit_limit
# {'D': 35982.491146299704, 'G': 40937.70269855061, 'F': 37326.32136401208, 'E': 37307.9895804746, 'C': 35123.91867189425, 'B': 34910.02246973629, 'A': 39895.76236730003}
#
# num_bc_sats
# {'D': 4.507098904678877, 'G': 4.759168616545391, 'F': 4.529731008792745, 'E': 4.565093054149192, 'C': 4.600323188130633, 'B': 4.651898084345996, 'A': 4.807758970197977}
#
# fico_range_high
# {'D': 686.2679105080365, 'G': 678.1051410900657, 'F': 680.6429293393365, 'E': 683.8899854964802, 'C': 692.4097994440032, 'B': 703.8103797622464, 'A': 738.0515053203113}
#
# dti
# {'D': 17.94405363056299, 'G': 18.177093158098184, 'F': 18.14907562253044, 'E': 18.26736460433702, 'C': 17.459863185067643, 'B': 16.47240475507248, 'A': 14.68395165492767}
#
# mo_sin_rcnt_tl
# {'D': 7.366484622115132, 'G': 5.7664441011714125, 'F': 6.318906863023567, 'E': 7.007563723271595, 'C': 8.16997958095317, 'B': 8.970557937868312, 'A': 9.549457974311348}
#
# purpose
# {'D': 0.05382061545917511, 'G': 0.059321105527639265, 'F': 0.0575369291555601, 'E': 0.05541605292014459, 'C': 0.051505588760934605, 'B': 0.050187742732187915, 'A': 0.04970287616199228}
#
# mo_sin_rcnt_rev_tl_op
# {'D': 12.003110681407193, 'G': 9.90921563942241, 'F': 10.621509358423376, 'E': 11.524701208775982, 'C': 13.137331475103515, 'B': 14.063997684943251, 'A': 15.695955079503934}
#
# pub_rec_bankruptcies
# {'D': 0.11070750450695234, 'G': 0.08937165429714676, 'F': 0.09478393113115778, 'E': 0.1054009062636661, 'C': 0.12173062921470171, 'B': 0.1029138041460968, 'A': 0.03063620747259203}
#
# num_accts_ever_120_pd
# {'D': 0.4450970936096149, 'G': 0.48342726146462417, 'F': 0.45112093047017116, 'E': 0.4535074883117333, 'C': 0.41381797718212027, 'B': 0.3778664538008494, 'A': 0.2497682178848415}
#
# chargeoff_within_12_mths
# {'D': 0.0, 'G': 0.0, 'F': 0.0, 'E': 0.0, 'C': 0.0, 'B': 0.0, 'A': 0.0}
#
# revol_bal
# {'D': 15160.380715612568, 'G': 18760.668882875914, 'F': 16377.401405862332, 'E': 16360.29269340977, 'C': 15056.384186358115, 'B': 14960.754078943834, 'A': 15556.966400511017}
#
# num_il_tl
# {'D': 8.021643415420805, 'G': 8.412026091665028, 'F': 8.086415402775424, 'E': 8.147756728706952, 'C': 7.942710902574489, 'B': 7.891764396491579, 'A': 8.585752126196374}
#
# num_actv_bc_tl
# {'D': 3.7375061075242253, 'G': 3.998599026740656, 'F': 3.811150227341205, 'E': 3.7969272141926043, 'C': 3.7259308939840583, 'B': 3.6929105177434085, 'A': 3.514977607824007}
#
# mths_since_last_record
# {'D': 76.51450239960413, 'G': 76.43731443452354, 'F': 76.88737434821567, 'E': 76.58368433788827, 'C': 76.66499631588287, 'B': 77.2475297391204, 'A': 77.1899945942195}
#
# revol_util
# {'D': 0.6352401245646061, 'G': 0.6954315341307283, 'F': 0.6767355310600471, 'E': 0.6595816588908273, 'C': 0.5996460044186003, 'B': 0.5424638013396424, 'A': 0.39550078475896844}
#
# collections_12_mths_ex_med
# {'D': 0.0, 'G': 0.0, 'F': 0.0, 'E': 0.0, 'C': 0.0, 'B': 0.0, 'A': 0.0}
#
# delinq_2yrs
# {'D': 0.30357806316129554, 'G': 0.40162350212601466, 'F': 0.35045483782045395, 'E': 0.32760267430754536, 'C': 0.2812648927720413, 'B': 0.22934439487620986, 'A': 0.11188623106792853}
#
# tot_coll_amt
# {'D': 98.17728148901895, 'G': 88.56774156426573, 'F': 92.80368766919734, 'E': 96.96849427844533, 'C': 95.85846016599865, 'B': 95.82729517970654, 'A': 80.83352683014543}
#
# num_op_rev_tl
# {'D': 8.132164364308304, 'G': 8.704949916496355, 'F': 8.283572978421375, 'E': 8.268988970716768, 'C': 8.09459208759651, 'B': 8.10310316466497, 'A': 8.07331943233185}
#
# inq_last_6mths
# {'D': 1.0193522332606413, 'G': 1.5539234634712022, 'F': 1.338325829275016, 'E': 1.1358024691358024, 'C': 0.8766481334392375, 'B': 0.6572400059134035, 'A': 0.54603372051976}
#
# sub_grade
# {'D': 0.07644745497133247, 'G': 0.14688643216080918, 'F': 0.12534119268583446, 'E': 0.09714930489225004, 'C': 0.05394302025416618, 'B': 0.03409113337337672, 'A': 0.016961903881399537}
#
# mo_sin_old_il_acct
# {'D': 124.58237334406644, 'G': 122.62585989344785, 'F': 122.18170277687278, 'E': 124.38697725797627, 'C': 126.29102885017815, 'B': 127.00041519985814, 'A': 131.13580119272885}
#
# total_bal_ex_mort
# {'D': 44363.63835856516, 'G': 52614.750814755644, 'F': 46902.793528814815, 'E': 46733.52811558252, 'C': 43144.77521930638, 'B': 42425.280046885826, 'A': 47091.51992033537}
#
# mths_since_last_major_derog
# {'D': 41.97723816461684, 'G': 41.43368046704199, 'F': 41.79005679966719, 'E': 41.79171842947977, 'C': 41.98259512002043, 'B': 41.97950557547306, 'A': 42.01198325204488}
#
# home_ownership
# {'D': 0.0523540408691155, 'G': 0.0517451488210281, 'F': 0.05247708352475623, 'E': 0.052095992076124205, 'C': 0.05185797259736795, 'B': 0.05169108467479357, 'A': 0.050484607238352366}
#
# pub_rec
# {'D': 0.17013165333979485, 'G': 0.15307305759567066, 'F': 0.1475696039694937, 'E': 0.16579999292511233, 'C': 0.17230937251787132, 'B': 0.13659092292574332, 'A': 0.039116475314764074}
#
# tot_hi_cred_lim
# {'D': 148938.78485222496, 'G': 161280.47536279468, 'F': 146530.2411311165, 'E': 153237.45521622192, 'C': 156030.72532496133, 'B': 164224.53002046768, 'A': 209123.962153244}
#
# mo_sin_old_rev_tl_op
# {'D': 174.3304753028173, 'G': 176.62212010701583, 'F': 170.04908780921696, 'E': 174.6394858805207, 'C': 179.5016917328517, 'B': 183.44965042252363, 'A': 193.98711676869036}
#
# num_tl_30dpd
# {'D': 0.0003822247574176661, 'G': 0.0004934178752011771, 'F': 0.0004184157526001686, 'E': 0.00042260908790004744, 'C': 0.00036608227494051404, 'B': 0.0004885323030388381, 'A': 0.0007295912607699105}
#
# open_acc
# {'D': 11.048477505855747, 'G': 12.115964437572478, 'F': 11.357162547091795, 'E': 11.261381725565107, 'C': 10.985107227958697, 'B': 10.904863774316697, 'A': 11.081695775689623}
#
# acc_open_past_24mths
# {'D': 4.44078788800867, 'G': 5.268589202402165, 'F': 4.861159971428443, 'E': 4.6386996898414345, 'C': 4.159042102627794, 'B': 3.8562454326059683, 'A': 3.624814338632981}
#
# total_acc
# {'D': 24.34787173895485, 'G': 26.49284885968303, 'F': 24.85252228245888, 'E': 24.94219816760409, 'C': 24.64515488482923, 'B': 24.677345577556896, 'A': 26.030308124191027}
#
# CO18M
# {'D': 0.07643970600113076, 'G': 0.14688828759180517, 'F': 0.12533308830285766, 'E': 0.0971382079309491, 'C': 0.05395154884829229, 'B': 0.034071639143252196, 'A': 0.01697792869269949}
#
# avg_cur_bal
# {'D': 12106.194948939625, 'G': 12472.835328634157, 'F': 11852.821779777902, 'E': 12375.936581067139, 'C': 12837.978104192345, 'B': 13393.507660943496, 'A': 16484.28432787175}
#
# disbursement_method
# {'D': 0.05169999999998428, 'G': 0.051699999999998206, 'F': 0.05169999999999244, 'E': 0.05169999999998635, 'C': 0.05169999999998361, 'B': 0.05169999999998348, 'A': 0.05169999999998435}
#
# zip_code
# {'D': 0.052100775381636995, 'G': 0.051904793196752876, 'F': 0.05193562436828077, 'E': 0.05187508224557052, 'C': 0.051898891977755796, 'B': 0.05159893993546613, 'A': 0.050967972230163604}
#
# mths_since_last_delinq
# {'D': 33.91895258915379, 'G': 31.67352236687981, 'F': 32.857185619676656, 'E': 33.49412315785962, 'C': 34.146912222165334, 'B': 34.62938773072202, 'A': 35.2542658609733}
#
# fico_range_low
# {'D': 682.2679105080365, 'G': 674.1051410900657, 'F': 676.6429293393365, 'E': 679.8899854964802, 'C': 688.4097994440032, 'B': 699.8103797622464, 'A': 734.0515053203113}
#
# num_rev_accts
# {'D': 14.758272031551233, 'G': 15.57995295806455, 'F': 14.743520153171417, 'E': 14.933065103894982, 'C': 14.997595931988966, 'B': 15.191805613845993, 'A': 15.505397725285732}
#
# mths_since_recent_bc_dlq
# {'D': 40.03995718048929, 'G': 39.0491933095476, 'F': 39.64104479665848, 'E': 39.915282808767216, 'C': 40.19886770637299, 'B': 40.389150565564904, 'A': 40.43190135227277}
#
# delinq_amnt
# {'D': 0.0, 'G': 0.0, 'F': 0.0, 'E': 0.0, 'C': 0.0, 'B': 0.0, 'A': 0.0}
#
# grade
# {'D': 0.07639999999994132, 'G': 0.14690000000000186, 'F': 0.12529999999999297, 'E': 0.09709999999996487, 'C': 0.05400000000006723, 'B': 0.03409999999994775, 'A': 0.017000000000024315}
#
# tax_liens
# {'D': 0.025410366703637187, 'G': 0.029377657518361036, 'F': 0.023066135329289736, 'E': 0.02635599071694508, 'C': 0.02118973397844799, 'B': 0.015107767497905105, 'A': 0.004059385153679221}
#
# bc_util
# {'D': 72.68325526760646, 'G': 77.27836724597356, 'F': 76.47874742753493, 'E': 74.69108558022604, 'C': 69.23679446297945, 'B': 63.69401884361446, 'A': 50.326393963127146}
#
# num_bc_tl
# {'D': 8.427320698952975, 'G': 8.846912161845195, 'F': 8.403863550485827, 'E': 8.481115650072603, 'C': 8.686587767422706, 'B': 8.937723106443869, 'A': 9.301049901074732}
#
# term
# {'D': 0.05522447298282636, 'G': 0.06644313877077573, 'F': 0.06312028852339106, 'E': 0.060516141356234246, 'C': 0.05290839952339676, 'B': 0.04795033262888821, 'A': 0.046183744894011336}
#
# annual_inc
# {'D': 69561.291745578, 'G': 84958.62263625822, 'F': 75499.49977487825, 'E': 73751.94566804633, 'C': 69287.7941766283, 'B': 70335.56408990122, 'A': 79683.34781001532}
#
# bc_open_to_buy
# {'D': 5103.942809177966, 'G': 4320.744777382569, 'F': 4183.172695849501, 'E': 4693.5317748839025, 'C': 6244.375982313104, 'B': 8233.838884581326, 'A': 15997.991934371033}
#
# int_rate
# {'D': 0.17778328729510118, 'G': 0.2505926942404348, 'F': 0.23568946062666246, 'E': 0.20698325020340422, 'C': 0.14849459094528447, 'B': 0.11638169540754668, 'A': 0.0760084553447064}
#
# num_tl_90g_dpd_24m
# {'D': 0.07898002029602474, 'G': 0.09121641149448045, 'F': 0.08477957028344832, 'E': 0.08519321378361112, 'C': 0.07558803941148583, 'B': 0.06761086937213567, 'A': 0.044344502381581365}
#
# acc_now_delinq
# {'D': 0.0, 'G': 0.0, 'F': 0.0, 'E': 0.0, 'C': 0.0, 'B': 0.0, 'A': 0.0}
#
# mths_since_recent_inq
# {'D': 6.138331790901824, 'G': 4.402247785764173, 'F': 4.855388186969653, 'E': 5.703662918132115, 'C': 6.768010883044769, 'B': 7.681300709896556, 'A': 8.154583446596108}
#
# mths_since_recent_revol_delinq
# {'D': 35.82773071127829, 'G': 34.466205362397154, 'F': 35.25405877000159, 'E': 35.651799264567565, 'C': 35.957900214172405, 'B': 36.16753980787196, 'A': 36.314195768013164}
#
# total_bc_limit
# {'D': 16074.283543472866, 'G': 16876.733225762706, 'F': 15405.02896680481, 'E': 16202.648329375872, 'C': 17562.76155672396, 'B': 19879.094745110888, 'A': 28913.873248959746}
#
# emp_length
# {'D': 0.051687115741858386, 'G': 0.05122632392732782, 'F': 0.05140566939263639, 'E': 0.05154484771304988, 'C': 0.051658512708453244, 'B': 0.05179722765727579, 'A': 0.051863549563778893}
#
# addr_state
# {'D': 0.05181609886116319, 'G': 0.051755856204097415, 'F': 0.05179179454194287, 'E': 0.051733234284907115, 'C': 0.05173852065131743, 'B': 0.051709237953623644, 'A': 0.0514388021314909}
#
# percent_bc_gt_75
# {'D': 61.42863252519268, 'G': 67.62054441020712, 'F': 66.79908564027038, 'E': 64.17717397022318, 'C': 56.38638286620476, 'B': 48.85337719715054, 'A': 33.34364553594337}
#
# num_sats
# {'D': 11.250487535247322, 'G': 12.184637222451345, 'F': 11.467654986247803, 'E': 11.443165467251518, 'C': 11.165293160311222, 'B': 11.182892602326278, 'A': 11.516567697663003}
#
# application_type
# {'D': 0.05169999999998428, 'G': 0.051699999999998206, 'F': 0.05169999999999244, 'E': 0.05169999999998635, 'C': 0.05169999999998361, 'B': 0.05169999999998348, 'A': 0.05169999999998435}
#
# tot_cur_bal
# {'D': 125048.94691154308, 'G': 137337.6142885379, 'F': 124061.58976120391, 'E': 129508.53336298377, 'C': 130207.88665321378, 'B': 135097.4635451154, 'A': 167101.141297969}
#
# pct_tl_nvr_dlq
# {'D': 94.24800937364165, 'G': 94.27598815161178, 'F': 94.19973284279067, 'E': 94.22500249190824, 'C': 94.40672694627537, 'B': 95.04574633288101, 'A': 96.70017221208165}
#
# installment
# {'D': 449.68360810921746, 'G': 638.7299884035559, 'F': 549.4730956537707, 'E': 515.9893950971117, 'C': 425.6571875496286, 'B': 405.3353694572683, 'A': 406.3752130645837}
#
# num_tl_120dpd_2m
# {'D': 0.00012233176688799562, 'G': 0.00013761225837309734, 'F': 0.00012311796545256306, 'E': 0.00013217759589387283, 'C': 0.00012667070244305108, 'B': 0.00015009071598254064, 'A': 0.00021311351045441484}
#
# num_actv_rev_tl
# {'D': 5.989133600537473, 'G': 6.485940357565861, 'F': 6.198866230992996, 'E': 6.1434096330431505, 'C': 5.837996237032427, 'B': 5.603935981875936, 'A': 5.08724128943094}
#
# earliest_cr_line_R
# {'D': -183.34475405863824, 'G': -186.758407421724, 'F': -180.61527152439584, 'E': -184.74901835933355, 'C': -187.96288721207307, 'B': -190.52776255946014, 'A': -201.3918539561936}
#
# num_rev_tl_bal_gt_0
# {'D': 5.979200910693307, 'G': 6.4952084858020545, 'F': 6.197585809630058, 'E': 6.135419217588704, 'C': 5.813990346183312, 'B': 5.593552320672778, 'A': 5.08293484289497}
#
# num_tl_op_past_12m
# {'D': 2.0790255458652465, 'G': 2.6328725088011082, 'F': 2.3927315238113733, 'E': 2.2055796880007073, 'C': 1.8751957635624428, 'B': 1.6969498956598108, 'A': 1.5767393347619494}
#
# mths_since_recent_bc
# {'D': 23.30444434694467, 'G': 19.90269039290866, 'F': 22.01116898614149, 'E': 22.763763493467376, 'C': 24.338327123345717, 'B': 25.24229474664859, 'A': 27.09535329607887}

# %% [markdown]
# #### Review Field types in final dataset to make sure scoring datasets will behave correctly (to be incorporated into Part 3)

# %%
print('Integers:')
for i in dTypeDict:
    if 'int' in dTypeDict[i]:
        print(i + ' - ' + dTypeDict[i])
print()
print('Float:')
for i in dTypeDict:
    if 'float' in dTypeDict[i]:
        print(i + ' - ' + dTypeDict[i])
print()
print('Other:')
for i in dTypeDict:
    if 'float' not in dTypeDict[i] and 'int' not in dTypeDict[i]:
        print(i + ' - ' + dTypeDict[i])
# Out:
# Integers:
# pub_rec_imputed - int64
# pct_tl_nvr_dlq_floor - int64
# tot_hi_cred_lim_imputed - int64
# num_il_tl_floor - int64
# annual_inc_imputed - int64
# open_acc_floor - int64
# delinq_amnt_imputed - int64
# mths_since_last_delinq_imputed - int64
# percent_bc_gt_75_cap - int64
# tot_hi_cred_lim_cap - int64
# num_tl_90g_dpd_24m_cap - int64
# bc_open_to_buy_floor - int64
# num_accts_ever_120_pd_imputed - int64
# sub_grade_imputed - int64
# num_tl_op_past_12m_cap - int64
# avg_cur_bal_floor - int64
# mort_acc_floor - int64
# pub_rec_bankruptcies_imputed - int64
# mo_sin_old_rev_tl_op_imputed - int64
# revol_bal_floor - int64
# num_op_rev_tl_cap - int64
# acc_now_delinq_cap - int64
# total_il_high_credit_limit_imputed - int64
# mo_sin_rcnt_rev_tl_op_imputed - int64
# num_rev_tl_bal_gt_0_cap - int64
# term_imputed - int64
# num_bc_sats_floor - int64
# acc_open_past_24mths_cap - int64
# bc_util_cap - int64
# mths_since_recent_revol_delinq_imputed - int64
# inq_last_6mths_cap - int64
# num_tl_op_past_12m_imputed - int64
# num_rev_tl_bal_gt_0_floor - int64
# total_bal_ex_mort_floor - int64
# grade_imputed - int64
# num_op_rev_tl_floor - int64
# acc_open_past_24mths_floor - int64
# total_bc_limit_floor - int64
# tax_liens_floor - int64
# delinq_amnt_cap - int64
# revol_bal_cap - int64
# open_acc_cap - int64
# annual_inc_floor - int64
# total_acc_floor - int64
# num_tl_120dpd_2m_floor - int64
# mths_since_last_delinq_cap - int64
# mths_since_recent_inq_floor - int64
# num_actv_rev_tl_cap - int64
# tot_hi_cred_lim_floor - int64
# mo_sin_rcnt_tl_cap - int64
# dti_cap - int64
# disbursement_method_imputed - int64
# revol_util_cap - int64
# open_acc_imputed - int64
# earliest_cr_line_R_cap - int64
# num_accts_ever_120_pd_floor - int64
# num_bc_sats_cap - int64
# tax_liens_cap - int64
# num_tl_30dpd_cap - int64
# mo_sin_rcnt_tl_imputed - int64
# pct_tl_nvr_dlq_imputed - int64
# num_rev_accts_imputed - int64
# home_ownership_imputed - int64
# fico_range_high_cap - int64
# num_tl_op_past_12m_floor - int64
# bc_util_floor - int64
# pub_rec_bankruptcies_cap - int64
# num_actv_rev_tl_floor - int64
# bc_open_to_buy_imputed - int64
# dti_imputed - int64
# mo_sin_rcnt_rev_tl_op_cap - int64
# num_tl_30dpd_floor - int64
# num_actv_rev_tl_imputed - int64
# delinq_2yrs_floor - int64
# annual_inc_cap - int64
# avg_cur_bal_cap - int64
# mths_since_last_major_derog_cap - int64
# bc_util_imputed - int64
# num_bc_tl_cap - int64
# mths_since_recent_revol_delinq_cap - int64
# num_tl_90g_dpd_24m_imputed - int64
# revol_bal_imputed - int64
# acc_now_delinq_floor - int64
# delinq_2yrs_imputed - int64
# tot_cur_bal_floor - int64
# chargeoff_within_12_mths_imputed - int64
# total_bc_limit_cap - int64
# num_tl_90g_dpd_24m_floor - int64
# application_type_imputed - int64
# mths_since_recent_bc_floor - int64
# num_rev_accts_floor - int64
# inq_last_6mths_imputed - int64
# mths_since_last_delinq_floor - int64
# delinq_amnt_floor - int64
# zip_code_imputed - int64
# total_il_high_credit_limit_floor - int64
# bc_open_to_buy_cap - int64
# mths_since_last_record_cap - int64
# num_rev_tl_bal_gt_0_imputed - int64
# verification_status_imputed - int64
# revol_util_floor - int64
# avg_cur_bal_imputed - int64
# pub_rec_cap - int64
# addr_state_imputed - int64
# total_bal_ex_mort_cap - int64
# mo_sin_rcnt_rev_tl_op_floor - int64
# total_rev_hi_lim_floor - int64
# num_bc_tl_floor - int64
# total_acc_imputed - int64
# collections_12_mths_ex_med_imputed - int64
# num_accts_ever_120_pd_cap - int64
# tax_liens_imputed - int64
# num_bc_tl_imputed - int64
# tot_coll_amt_imputed - int64
# num_rev_accts_cap - int64
# pub_rec_floor - int64
# emp_length_imputed - int64
# mths_since_last_major_derog_floor - int64
# inq_last_6mths_floor - int64
# purpose_imputed - int64
# mths_since_recent_revol_delinq_floor - int64
# percent_bc_gt_75_floor - int64
# revol_util_imputed - int64
# mths_since_recent_bc_imputed - int64
# tot_coll_amt_floor - int64
# fico_range_high_floor - int64
# tot_coll_amt_cap - int64
# mths_since_recent_inq_imputed - int64
# mo_sin_old_il_acct_floor - int64
# num_sats_imputed - int64
# chargeoff_within_12_mths_floor - int64
# total_il_high_credit_limit_cap - int64
# mort_acc_imputed - int64
# total_acc_cap - int64
# num_tl_120dpd_2m_imputed - int64
# tot_cur_bal_cap - int64
# acc_now_delinq_imputed - int64
# collections_12_mths_ex_med_cap - int64
# mths_since_recent_bc_dlq_imputed - int64
# earliest_cr_line_R_floor - int64
# mo_sin_old_il_acct_imputed - int64
# fico_range_low_floor - int64
# mths_since_recent_bc_cap - int64
# mths_since_last_record_imputed - int64
# num_il_tl_imputed - int64
# num_tl_120dpd_2m_cap - int64
# mths_since_last_record_floor - int64
# num_actv_bc_tl_cap - int64
# fico_range_high_imputed - int64
# delinq_2yrs_cap - int64
# mo_sin_old_rev_tl_op_cap - int64
# earliest_cr_line_R_imputed - int64
# num_actv_bc_tl_floor - int64
# tot_cur_bal_imputed - int64
# mort_acc_cap - int64
# dti_floor - int64
# fico_range_low_imputed - int64
# num_op_rev_tl_imputed - int64
# acc_open_past_24mths_imputed - int64
# pub_rec_bankruptcies_floor - int64
# percent_bc_gt_75_imputed - int64
# mo_sin_old_il_acct_cap - int64
# mths_since_recent_bc_dlq_floor - int64
# mths_since_last_major_derog_imputed - int64
# total_rev_hi_lim_cap - int64
# collections_12_mths_ex_med_floor - int64
# pct_tl_nvr_dlq_cap - int64
# mths_since_recent_bc_dlq_cap - int64
# num_sats_floor - int64
# num_il_tl_cap - int64
# total_rev_hi_lim_imputed - int64
# fico_range_low_cap - int64
# mo_sin_old_rev_tl_op_floor - int64
# num_sats_cap - int64
# num_bc_sats_imputed - int64
# mo_sin_rcnt_tl_floor - int64
# mths_since_recent_inq_cap - int64
# total_bc_limit_imputed - int64
# num_tl_30dpd_imputed - int64
# total_bal_ex_mort_imputed - int64
# num_actv_bc_tl_imputed - int64
# chargeoff_within_12_mths_cap - int64
#
# Float:
# loan_amnt - float64
# mo_sin_rcnt_tl - float64
# purpose - float64
# fico_range_high - float64
# revol_util - float64
# annual_inc - float64
# disbursement_method - float64
# mths_since_last_major_derog - float64
# mths_since_last_record - float64
# pub_rec - float64
# open_acc - float64
# total_acc - float64
# num_tl_90g_dpd_24m - float64
# member_id - float64
# num_rev_accts - float64
# num_rev_tl_bal_gt_0 - float64
# bc_open_to_buy - float64
# int_rate - float64
# pub_rec_bankruptcies - float64
# num_sats - float64
# tot_coll_amt - float64
# total_il_high_credit_limit - float64
# pct_tl_nvr_dlq - float64
# total_bal_ex_mort - float64
# mo_sin_old_rev_tl_op - float64
# num_tl_30dpd - float64
# bc_util - float64
# zip_code - float64
# application_type - float64
# acc_now_delinq - float64
# mths_since_last_delinq - float64
# tax_liens - float64
# tot_cur_bal - float64
# num_tl_120dpd_2m - float64
# mort_acc - float64
# mo_sin_rcnt_rev_tl_op - float64
# num_accts_ever_120_pd - float64
# mths_since_recent_bc - float64
# revol_bal - float64
# num_actv_bc_tl - float64
# term - float64
# inq_last_6mths - float64
# num_il_tl - float64
# dti - float64
# loan_age - float64
# mths_since_recent_bc_dlq - float64
# num_bc_tl - float64
# mths_since_recent_revol_delinq - float64
# acc_open_past_24mths - float64
# emp_length - float64
# percent_bc_gt_75 - float64
# installment - float64
# verification_status - float64
# num_actv_rev_tl - float64
# total_rev_hi_lim - float64
# num_bc_sats - float64
# mo_sin_old_il_acct - float64
# avg_cur_bal - float64
# collections_12_mths_ex_med - float64
# delinq_2yrs - float64
# num_op_rev_tl - float64
# sub_grade - float64
# home_ownership - float64
# tot_hi_cred_lim - float64
# chargeoff_within_12_mths - float64
# delinq_amnt - float64
# fico_range_low - float64
# grade - float64
# num_tl_op_past_12m - float64
# mths_since_recent_inq - float64
# total_bc_limit - float64
# addr_state - float64
# earliest_cr_line_R - float64
#
# Other:

# %% [markdown]
# #### Graphically review target and Lending Club grade to make sure expected sloping is seen

# %%
# Have Bokeh outputs occur in notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="127c3797-373c-4dbe-9ff2-066f1fd83d03">Loading BokehJS ...</span>
#     </div>

# %%
#Temporarily add back orginal grade to help review dataq
dfFinal['LC_Grades'] = df['grade']

# %%
view = dfFinal.groupby('LC_Grades').agg({'CO18M':['mean','size']})

# %%
p1 = figure(x_range=list(view.index.values), title="18M CO% by Lending Club Grades", plot_width=600, plot_height=300)
p2 = figure(x_range=list(view.index.values), title="Number of Loans by Lending Club Grade(k)", plot_width=600, plot_height=300)
p1.vbar(x=list(view.index.values), top=list(view['CO18M']['mean'].values), width=0.9)
p2.line(x=list(view.index.values), y=list((view['CO18M']['size']/1000).values))
show(p1)
show(p2)
# Out:
#   <div class="bk-root" id="3510f319-f751-4884-adcf-6deac9c2da54"></div>
#   <div class="bk-root" id="58240252-6424-486c-a5bb-fbeed1503b69"></div>

# %%
#Remove 'grade_Group' from final df
dfFinal = dfFinal.drop('LC_Grades', 1)
